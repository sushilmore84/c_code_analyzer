# %% [markdown]
# # Explore AST Parsing
#
# This notebook demonstrates AST parsing of C code.

# %%
import sys
sys.path.insert(0, '../src')

from claims_analyzer.ast_parser import ClaimsSystemParser

# %%
# Initialize parser
parser = ClaimsSystemParser('../../claims_system')
print(f"Parser initialized for: {parser.source_dir}")

# %%
# TODO: Add your analysis code here
# functions = parser.parse_all_files()
# print(f"Found {len(functions)} functions")
